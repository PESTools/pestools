# %% [markdown]
# ###Examples for the Rei class
# The Rei class uses the Res class to aggregate residuals information for each PEST iteration
# * the **plot_one2ones()** method creates plots using the **plot_one2one** method in Res
# * information on observation type (e.g. heads, fluxes) and also x, y location can be added via an observation information file
# * the **obsinfo** attribute (dataframe) has the location and/or type of all observation, read in from the observation information file
# * the get_phi method builds dataframes of phi by observation group, observation type, and objective function component (**phi_by_group**, **phi_by_type**, and **phi_by_component** attributes)
# * a method to return residuals information for all observations across all iterations could easily be added to this framework, but not sure how we would use it

# %%
import sys
sys.path.append('../pst_tools')
from rei import *

% matplotlib inline
rei = Rei('../cc/columbia_svda', obs_info_file='../cc/observation_locations.csv')
#rei = Rei('../cc/columbia_svda') # test without an observation info file
rei.reifiles
# Out:
# {0: '../cc/columbia.rei',
#  1: '../cc/columbia_svda.rei.1',
#  2: '../cc/columbia_svda.rei.2',
#  3: '../cc/columbia_svda.rei.3',
#  4: '../cc/columbia_svda.rei.4',
#  5: '../cc/columbia_svda.rei.5',
#  6: '../cc/columbia_svda.rei.6',
#  7: '../cc/columbia_svda.rei.7',
#  8: '../cc/columbia_svda.rei.8',
#  9: '../cc/columbia_svda.rei.9',
#  10: '../cc/columbia_svda.rei.10',
#  11: '../cc/columbia_svda.rei.11',
#  12: '../cc/columbia_svda.rei.12',
#  13: '../cc/columbia_svda.rei.13',
#  14: '../cc/columbia_svda.rei.14',
#  15: '../cc/columbia_svda.rei.15',
#  16: '../cc/columbia_svda.rei.16'}

# %% [markdown]
# ###Make a one-to-one plot of the WCRs1 group for each iteration:

# %%
rei.plot_one2ones('WCRs1')
# Out:
# plotting...
# ../cc/columbia.rei
# ../cc/columbia_svda.rei.1
# ../cc/columbia_svda.rei.2
# ../cc/columbia_svda.rei.3
# ../cc/columbia_svda.rei.4
# ../cc/columbia_svda.rei.5
# ../cc/columbia_svda.rei.6
# ../cc/columbia_svda.rei.7
# ../cc/columbia_svda.rei.8
# ../cc/columbia_svda.rei.9
# ../cc/columbia_svda.rei.10
# ../cc/columbia_svda.rei.11
# ../cc/columbia_svda.rei.12
# ../cc/columbia_svda.rei.13
# ../cc/columbia_svda.rei.14
# ../cc/columbia_svda.rei.15
# ../cc/columbia_svda.rei.16
# saved to columbia_svda_reis.pdf

# %%
rei.get_phi()
# Out:
# getting phi by group for each iteration...
# ../cc/columbia.rei
# ../cc/columbia_svda.rei.1
# ../cc/columbia_svda.rei.2
# ../cc/columbia_svda.rei.3
# ../cc/columbia_svda.rei.4
# ../cc/columbia_svda.rei.5
# ../cc/columbia_svda.rei.6
# ../cc/columbia_svda.rei.7
# ../cc/columbia_svda.rei.8
# ../cc/columbia_svda.rei.9
# ../cc/columbia_svda.rei.10
# ../cc/columbia_svda.rei.11
# ../cc/columbia_svda.rei.12
# ../cc/columbia_svda.rei.13
# ../cc/columbia_svda.rei.14
# ../cc/columbia_svda.rei.15
# ../cc/columbia_svda.rei.16

# %% [markdown]
# ###Phi contributions of observation groups for each iteration:

# %%
rei.phi_by_group
# Out:
#                       wcrs1  wcrs2         dhdz   head_best   head_fair  \
# Pest iteration
# 0               2042.348710      0  2305.846330  257.740780  962.185430
# 1               1448.160663      0  1663.059048  113.995016  586.543971
# 2               1365.611336      0  1944.295106  193.167830  627.503030
# 3               1280.485259      0  1553.594525  170.118444  631.056470
# 4               1223.443697      0  1023.951474  120.682434  563.065960
# 11               7.757820  190.129854  114.488361  25.735076  143.449182
# 12               5.312319  195.535419   99.964523  17.595027  125.723043
# 13               6.269797  208.246500  108.622428  21.883611  140.354516
# 14              10.835788  167.237767   74.559416  17.054955   36.487157
# 15               7.429814   83.833547   53.446971  13.388389   47.868362
# 16               8.234163  122.537417   79.417897  16.021742   76.679015
#
#                 regul_rech
# Pest iteration
# 0                 0.000000
# 1                18.725629
# 2                67.868188
# 3                 0.485767
# 4                 0.065852
# 5                 1.103657
# 6                 3.290171
# 7                 7.506886
# 8                37.260891
# 9                 3.281620
# 10                0.159190
# 11                0.461530
# 12                0.092652
# 13                0.084985
# 14                0.289952
# 15                0.472184
# 16                0.354083
#
# [17 rows x 23 columns]

# %% [markdown]
# ###Phi contributions observation type:

# %%
rei.phi_by_type
# Out:
#                    baseflow         head  vertical head difference
# Pest iteration
# 0               3410.050984  4459.738774               2305.846330
# 1               1798.301498  2722.190306               1663.059048
# 2               1491.806103  2814.499375               1944.295106
# 3               1488.998883  2641.034922               1553.594525
# 4               1220.943797  2476.965979               1023.951474
# 5               1073.586614  2646.706753               1019.021073
# 6               1012.953739  2575.038617               1053.267711
# 7               1006.077688  2568.834200               1059.420877
# 8               1009.590981  2568.958196               1061.224710
# 9                918.827462  2484.816820                879.885304
# 10              1031.620188  2647.412496                720.126837
# 11               914.828327  2612.553484                796.362793
# 12               903.764604  2605.979044                687.776712
# 13               853.753261  2745.201569                751.766886
# 14              1170.235522  2799.478073               1610.720558
# 15              1079.129137  2612.745124               1103.631514
# 16               996.160491  2634.655021               1007.118587

# %% [markdown]
# ###Phi contributions by objection function component:

# %%
rei.phi_by_component
# Out:
#                 Measurement Phi  Regularisation Phi     Phi Total
# Pest iteration
# 0                  10175.636088        1.751817e-12  10175.636088
# 1                   6183.550852        2.500288e+02   6433.579612
# 2                   6250.600585        1.488104e+03   7738.704244
# 3                   5683.628330        3.127629e+02   5996.391250
# 4                   4721.861251        4.992495e+02   5221.110762
# 5                   4739.314440        1.576975e+03   6316.289701
# 6                   4641.260067        3.889195e+03   8530.455527
# 7                   4634.332765        3.374792e+03   8009.124531
# 8                   4639.773887        3.693559e+03   8333.332785
# 9                   4283.529586        1.115977e+03   5399.506716
# 10                  4399.159521        1.184702e+03   5583.861957
# 11                  4323.744604        1.481365e+03   5805.109448
# 12                  4197.520360        1.365887e+03   5563.407216
# 13                  4350.721717        1.348749e+03   5699.470911
# 14                  5580.434153        2.449203e+03   8029.637249
# 15                  4795.505775        7.432698e+02   5538.775546
# 16                  4637.934100        1.117124e+03   5755.057803

# %% [markdown]
# ###Example pandas plots of the above dataframes:

# %%
import seaborn as sb
ax = rei.phi_by_component.plot()
ax.set_ylabel("Phi")

# %%
ax = rei.phi_by_type.plot(kind='area')
ax.set_ylabel("Phi")

# %% [markdown]
# ####would be better to have a feature for the group plot where the types that each groups belong to can be more easily distinguished
# maybe a different color palette for the groups in each type? (blues for baseflow, greens for head, etc.)

# %%
ax = rei.phi_obs_by_group.plot(kind='bar', stacked=True)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
ax.set_ylabel("Phi")

# %%
# Out:
#                                   Type
# Group
# head_fair                         head
# head_poor                         head
# head_good                         head
# head_best                         head
# lrg_streams                   baseflow
# sm_streams                    baseflow
# zero_streams                  baseflow
# headwaters                    baseflow
# wcrs1                             head
# wcrs2                             head
# dhdz          vertical head difference
# cc_streams                    baseflow
