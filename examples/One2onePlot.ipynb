# %% [markdown]
# ###One-to-one plot of Measured vs. modelled results

# %%
import sys
sys.path.append('../pst_tools')
from res import *

% matplotlib inline

res = Res('../cc/Columbia.res')

# %% [markdown]
# ####plot one group using default settings

# %%
fig, ax = res.one2one_plot('WCRs1')

# %% [markdown]
# ####plot multiple groups using default settings

# %%
fig, ax = res.one2one_plot(['WCRs2', 'WCRs1'])

# %% [markdown]
# ####plot multiple groups with customized settings via a dictionary of Matplotlib keyword arguments

# %%
groupinfo_heads = {'head_best': {'marker': '^',
                                 's': 120,
                                 'c': 'r',
                                 'label': 'Heads, best',
                                 'zorder': 20},
                   'head_good': {'marker': 's',
                                 's': 60,
                                 'c': 'b',
                                 'label': 'Heads, good',
                                 'zorder': 19},
                   'head_fair': {'marker': 'o',
                                 's': 28,
                                 'c': '0.85',
                                 'label': 'Heads, fair',
                                 'zorder': 8,
                                 'alpha': 0.5},
                   'head_poor': {'marker': '+',
                                 's': 20,
                                 'c': 'k',
                                 'label': 'Heads, zero-weighted',
                                 'zorder': 7},
                   'head_zero': {'marker': '+',
                                 's': 20,
                                 'c': 'k',
                                 'label': 'Heads, zero-weighted',
                                 'zorder': 7},
                   'WCRs1': {'marker': 'o',
                             's': 28,
                             'c': '0.85',
                             'label': 'Heads, fair',
                             'zorder': 8,
                             'alpha': 0.5},
                   'WCRs2': {'marker': '+',
                             's': 20,
                             'c': 'k',
                             'label': 'Heads, zero-weighted',
                             'zorder': 7}
}
fig, ax = res.one2one_plot(groupinfo_heads)

# %% [markdown]
# ####save figure to pdf

# %%
fig.savefig('test.pdf')

# %% [markdown]
# ####plot multiple groups using other imported settings (e.g. from Seaborn)

# %%
import seaborn as sb
fig, ax = res.one2one_plot(groupinfo_heads.keys())

# %%
fig, ax = res.one2one_plot('wcrs1')
