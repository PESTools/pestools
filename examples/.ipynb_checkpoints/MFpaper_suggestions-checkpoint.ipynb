# %%
import sys
sys.path.append('../pestools')
import matplotlib.pyplot as plt
import matplotlib as mpl
from identpar import IdentPar
from res import *

% matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-c58dc15f28ad> in <module>()
#       4 import matplotlib as mpl
#       5 from identpar import IdentPar
# ----> 6 from res import *
#       7
#       8 get_ipython().magic(u'matplotlib inline')
#
# C:\Users\egc\pest_tools-1\pestools\res.py in <module>()
#       1 import matplotlib.pyplot as plt
#       2 import math
# ----> 3 from pest import *
#       4 import plots
#       5
#
# C:\Users\egc\pest_tools-1\pestools\pest.py in <module>()
#      13 from parsen import ParSen
#      14 from Cor import Cor
# ---> 15 from res import Res
#      16
#      17
#
# ImportError: cannot import name Res

# %%
mpl.rcParams['font.family'] = 'Arial'

# %%
res = Res('../cc/columbia_svda.rei.16', obs_info_file='../cc/observation_locations.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-778bf3d2db9f> in <module>()
# ----> 1 res = Res('../cc/columbia_svda.rei.16', obs_info_file='../cc/observation_locations.csv')
#
# NameError: name 'Res' is not defined

# %%
res.df.head()
# Out:
#                       Name      Group  Measured  Modelled   Residual  Weight  \
# 7089222501_b  7089222501_b  head_best    858.13  850.1707   7.959346     0.2
# 1089192101_b  1089192101_b  head_best    893.24  891.5156   1.724436     0.2
# 2089103101_b  2089103101_b  head_best    924.60  909.9240  14.675990     0.2
# 3089103201_b  3089103201_b  head_best    911.44  910.1028   1.337156     0.2
# 2089475301_b  2089475301_b  head_best    729.25  733.7051  -4.455139     0.2
#
#               Weighted_Residual  Absolute_Residual  \
# 7089222501_b           1.591869           7.959346
# 1089192101_b           0.344887           1.724436
# 2089103101_b           2.935198          14.675990
# 3089103201_b           0.267431           1.337156
# 2089475301_b          -0.891028           4.455139
#
#               Weighted_Absolute_Residual  Weighted_Sq_Residual
# 7089222501_b                    1.591869              2.534048
# 1089192101_b                    0.344887              0.118947
# 2089103101_b                    2.935198              8.615387
# 3089103201_b                    0.267431              0.071519
# 2089475301_b                    0.891028              0.793931

# %%
res.obsinfo.head()
# Out:
#                         X            Y  Type      Group
# 7089222501_b  570954.8275  296365.6586  head  head_best
# 1089192101_b  575025.8740  304202.1060  head  head_best
# 2089103101_b  586985.0743  304340.3521  head  head_best
# 3089103201_b  586962.2041  304370.9770  head  head_best
# 2089475301_b  536391.8551  305263.7315  head  head_best

# %%
fig, ax = res.plot_hexbin(['WCRs1'])

# %%
fig, axes = res.plot_hist(groupinfo=['head_best', 'head_good', 'head_fair', 'head_poor'], color='k')

# %% [markdown]
# ###Identifiability
# * Indentifiability is computed using Jeremy's errvar class in pyemu
# * ancillary information on parameters (such as location, zones, values, etc.) can be read in using the par_info_file argument

# %%
ip = IdentPar('../cc/columbia.jco', par_info_file='../cc/parinfo.csv')
# Out:
# 2015-03-31 18:39:05.784187 starting: pre-loading base components
# 2015-03-31 18:39:05.784285 starting: loading jco: ../cc/columbia.jco
# 2015-03-31 18:39:05.835419 finished: loading jco: ../cc/columbia.jco took: 0:00:00.051134
# 2015-03-31 18:39:05.835826 starting: loading pst: ../cc/columbia.pst
# 2015-03-31 18:39:05.868075 finished: loading pst: ../cc/columbia.pst took: 0:00:00.032249
# 2015-03-31 18:39:05.868144 starting: loading parcov
# 2015-03-31 18:39:05.955166 finished: loading parcov took: 0:00:00.087022
# 2015-03-31 18:39:05.955613 starting: loading obscov
# 2015-03-31 18:39:06.312481 finished: loading obscov took: 0:00:00.356868
# 2015-03-31 18:39:06.312851 finished: pre-loading base components took: 0:00:00.528664

# %% [markdown]
# ###Stacked bar chart

# %%
ip.plot_bar(nsingular=50)
# Out:
# 2015-03-31 18:39:06.316940 starting: qhalf
# 2015-03-31 18:39:06.324836 finished: qhalf took: 0:00:00.007896

# %% [markdown]
# ###Pilot Point coordinates brought in from the par_info_file

# %%
ip.parinfo.head()
# Out:
#                      X            Y  zone  initialK
# Name
# kpkpx_tc3  1985516.722  1203426.934    15  5.720760
# kpkpx_tc4  2012516.722  1203426.934    15  3.541445
# kpkpx_tc7  1958516.722  1176426.934    15  5.942886
# kpkpx_tc8  1985516.722  1176426.934    15  2.298416
# kpkpx_tc9  2012516.722  1176426.934    15  3.905260

# %% [markdown]
# ###Spatial plot of total pilot point identifiabilities for a given zone
# Support of shapefile overlays coming soon!
# (sorry, I failed to get this figured out for the paper)

# %%
tc = ip.ident_points.ix[ip.ident_points.zone == 15]
fig, ax = ip.plot_spatial(tc, nsingular=50)
