# %% [markdown]
# ###Demonstration of Pst (PEST control file) class:
# * reads run information from PEST control file
# * methods for reading basic control data, parameter data, and observation data are inherited from base class **Pest()**
# * could also add write method to write out a new PEST control file

# %%
import sys
sys.path.append('../pst_tools')
from pst import Pst
cpest = Pst('Columbia', run_folder='../cc')
cpest.read_pst()
# Out:
# reading ../cc/Columbia.pst...
# control data...
# parameter data...
# observation data...
# parameter groups...
# observation groups...
# batch file...
# template and instruction files...
# prior information...
# regularisation...

# %%
cpest.pardata
# Out:
#                 PARNME PARTRANS PARCHGLIM  PARVAL1       PARLBND  \
# WR_drnC        WR_drnC      log    factor     1.00  1.000000e-10
# kh_c              kh_c      log    factor    30.00  1.000000e-10
# kh_ca            kh_ca      log    factor    30.00  1.000000e-10
# kh_ca2          kh_ca2      log    factor    30.00  1.000000e-10
# kh_cr            kh_cr      log    factor    30.00  1.000000e-10
# kh_f              kh_f      log    factor    30.00  1.000000e-10
# kh_gg            kh_gg      log    factor    30.00  1.000000e-10
# kh_ghh          kh_ghh      log    factor    30.00  1.000000e-10
# kh_ghr          kh_ghr      log    factor    30.00  1.000000e-10
# kh_ghs          kh_ghs      log    factor    30.00  1.000000e-10
# kh_hp            kh_hp      log    factor    30.00  1.000000e-10
# kh_l              kh_l      log    factor    30.00  1.000000e-10
# kh_lca          kh_lca      log    factor    30.00  1.000000e-10
# ...

# %%
cpest.obsdata
# Out:
#                     OBSNME  OBSVAL  WEIGHT     OBGNME
# 0000891613_f  0000891613_f  985.00  0.0333  head_fair
# 0088473101_f  0088473101_f  788.00  0.0333  head_fair
# 0088473701_f  0088473701_f  822.00  0.0333  head_fair
# 0088473801_f  0088473801_f  880.00  0.0333  head_fair
# 0088475201_f  0088475201_f  898.00  0.0333  head_fair
# 0088480601_f  0088480601_f  850.00  0.0333  head_fair
# 0088481501_f  0088481501_f  827.00  0.0333  head_fair
# 0088482501_f  0088482501_f  897.00  0.0333  head_fair
# 0088482601_f  0088482601_f  949.00  0.0333  head_fair
# 0088484701_f  0088484701_f  805.00  0.0333  head_fair
# 0088491001_f  0088491001_f  814.00  0.0333  head_fair
# 0088500201_p  0088500201_p  883.00  0.0000  head_poor
# 0088503201_f  0088503201_f  805.00  0.0333  head_fair
# 0088504201_f  0088504201_f  864.00  0.0333  head_fair
# 0088505101_f  0088505101_f  750.00  0.0333  head_fair
# 0088512301_f  0088512301_f  865.00  0.0333  head_fair
# ...

# %%
cpest.basename
# Out:
# 'columbia_opt5_13best'
